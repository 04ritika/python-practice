# %% [markdown]
# <a href="https://colab.research.google.com/github/04ritika/python-practice/blob/main/pyprac2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time


def countdown(t):
  while t!=0:
    mins,secs=divmod(t,60)
    timer='{:02d}:{:02d}'.format(mins,secs)
    #print(timer,end='\r')
    print(timer)
    time.sleep(1)
    t-=1

  print('fire in the hole ')
t=input("enter the time in secs")
countdown(int(t))
# Out:
# enter the time in secs5
# 5
# 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3632562692.py in <cell line: 0>()
#      13   print('fire in the hole ')
#      14 t=input("enter the time in secs")
# ---> 15 countdown(int(t))
#      16
#
# /tmp/ipython-input-3632562692.py in countdown(t)
#       8     #print(timer,end='\r')
#       9     print(t)
# ---> 10     time.sleep(5)
#      11     t-=1
#      12
#
# KeyboardInterrupt:

# %%
pip install reportlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 33.9 MB/s eta 0:00:00
# ...

# %%
from reportlab.platypus import SimpleDocTemplate, Table, Paragraph, TableStyle

from reportlab.lib import colors
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.pagesizes import A4

#list of list
DATA = [
    [ "Date" , "Name", "Subscription", "Price (Rs.)" ],
    [
        "16/11/2020",
        "Full Stack Development with React & Node JS - Live",
        "Lifetime",
        "10,999.00/-",
    ],
    [ "16/11/2020", "Geeks Classes: Live Session", "6 months", "9,999.00/-"],
    [ "Sub Total", "", "", "20,9998.00/-"],
    [ "Discount", "", "", "-3,000.00/-"],
    [ "Total", "", "", "17,998.00/-"],
]


pdf=SimpleDocTemplate("receipt.pdf",pagesize=A4) #blank notebook named receipt.pdf


styles=getSampleStyleSheet()
title_style=styles["Heading1"]
title_style.alignment = 1

title=Paragraph("ritika",title_style)


style = TableStyle(
    [
        ( "BOX" , ( 0, 0 ), ( -1, -1 ), 1 , colors.black ),
        ( "GRID" , ( 0, 0 ), ( 4 , 4 ), 1 , colors.black ),
        ( "BACKGROUND" , ( 0, 0 ), ( 3, 0 ), colors.gray ),
        ( "TEXTCOLOR" , ( 0, 0 ), ( -1, 0 ), colors.whitesmoke ),
        ( "ALIGN" , ( 0, 0 ), ( -1, -1 ), "CENTER" ),
        ( "BACKGROUND" , ( 0 , 1 ) , ( -1 , -1 ), colors.beige ),
    ]
)

table= Table(DATA,style=style)
pdf.build([title,table])

# %%
from google.colab import files
files.download("receipt.pdf")

# %%
import hashlib

def hash_file(filename1,filename2):
  h1=hashlib.sha1()
  h2=hashlib.sha1()

  with open(filename1,"rb") as file:
    chunk=0
    while chunk!= b'':
      chunk=file.read(1024)
      h1.update(chunk)


  with open(filename2,"rb") as file:
    chunk=0
    while chunk!= b'':
      chunk=file.read(1024)
      h2.update(chunk)

    return h1.hexdigest(),h2.hexdigest()

msg1,msg2=hash_file("file1.txt","file1-copy.txt")
print(msg1,msg2)


if(msg1==msg2):
  print("identical")
else:
  print("not identical")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2691630375.py in <cell line: 0>()
#      20     return h1.hexdigest(),h2.hexdigest()
#      21
# ---> 22 msg1,msg2=hash_file("file1.txt","file1-copy.txt")
#      23 print(msg1,msg2)
#      24
#
# /tmp/ipython-input-2691630375.py in hash_file(filename1, filename2)
#       5   h2=hashlib.sha1()
#       6
# ----> 7   with open(filename1,"rb") as file:
#       8     chunk=0
#       9     while chunk!= b'':
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file1.txt'

# %% [markdown]
# # New Section
